# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnoiprem/honest-colab/blob/main/Telco_Case_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [link text](https://)# Telco Case Study by QuantumBlack

# %% [markdown]
# ### Question 1
#
# What might be the drivers for variation in network maintenance performance between regions?

# %% [markdown]
# *Your answer (non-coding):*

# %%
#event total time , longer time might be serious issue
#Network is not reachable
#NETWORK , netowrk tower is very far
#no of alrms
#sound is not clear
# its delay to reach signal

#

# %% [markdown]
# ### Question 2
#
# After working with Data Scientists and industry experts, we've agreed to uncover the drivers of engineering team performance using a model.  The first task is to assess the data available.
#
# What data quality issues would you be concerned about and check for?
#
# - What data quality issues would you be concerned about and check for?
# - Execute a test for completeness of data against the `Issue type` field in the alarms.json file

# %%
# Your answer
"..."

# number of records
#NOT NULL AN NULL
# mandatory field should not be null
#some Quality check query based on business usecase
#increment more zero records

#Business logic based on
# Out:
# '...'

# %%
# !pip3 install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.3.0.tar.gz (281.3 MB)
#      |████████████████████████████████| 281.3 MB 56 kB/s
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 64.4 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.0-py2.py3-none-any.whl size=281764026 sha256=03fee95952ce9e9b059a28f5f491221cddfbbe911d52250181112c303dab46d7
#   Stored in directory: /root/.cache/pip/wheels/7a/8e/1b/f73a52650d2e5f337708d9f6a1750d451a7349a867f928b885
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.3.0

# %%
from  pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.master("local[1]").appName("SQL").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://c6ac10a78798:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[1]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>SQL</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# !wget https://raw.githubusercontent.com/vishnoiprem/honest-colab/main/alarms.json
# Out:
# --2022-10-08 02:24:45--  https://raw.githubusercontent.com/vishnoiprem/honest-colab/main/alarms.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9785106 (9.3M) [text/plain]
# Saving to: ‘alarms.json’
#
# alarms.json         100%[===================>]   9.33M  --.-KB/s    in 0.03s
#
# 2022-10-08 02:24:45 (335 MB/s) - ‘alarms.json’ saved [9785106/9785106]

# %%
# !ls -lrt
# Out:
# total 9560
# drwxr-xr-x 1 root root    4096 Oct  5 13:35 sample_data
# -rw-r--r-- 1 root root 9785106 Oct  8 02:24 alarms.json

# %%
# !head alarms.json
# Out:
# [{"alarm_id":50000001,"event_start_ts":1525683343000,"event_end_ts":1525685613000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON75","MeContext":"LON75UTM3265"},"issue_type":""},{"alarm_id":50000002,"event_start_ts":1533610843000,"event_end_ts":1533618469000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON47","MeContext":"LON47UTM3159"},"issue_type":""},{"alarm_id":50000003,"event_start_ts":1541637429000,"event_end_ts":1541645693000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON75","MeContext":"LON75GSM2884"},"issue_type":"3g_failure"},{"alarm_id":50000004,"event_start_ts":1525599471000,"event_end_ts":1525604682000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON187","MeContext":"LON187GSM2391"},"issue_type":"power_failure"},{"alarm_id":50000005,"event_start_ts":1541335278000,"event_end_ts":1541342376000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON111","MeContext":"LON111LTE4170"},"issue_type":"power_failure"},{"alarm_id":50000006,"event_start_ts":1533841992000,"event_end_ts":1533844097000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON75","MeContext":"LON75GSM2884"},"issue_type":""},{"alarm_id":50000007,"event_start_ts":1530743892000,"event_end_ts":1530752968000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON33","MeContext":"LON33GSM2601"},"issue_type":"speed_issues"},{"alarm_id":50000008,"event_start_ts":1532227123000,"event_end_ts":1532234526000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON187","MeContext":"LON187LTE4202"},"issue_type":"power_failure"},{"alarm_id":50000009,"event_start_ts":1516535411000,"event_end_ts":1516540419000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON10","MeContext":"LON10UTM3870"},"issue_type":"high_temperature"},{"alarm_id":50000010,"event_start_ts":1540331010000,"event_end_ts":1540334084000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON37","MeContext":"LON37GSM2364"},"issue_type":"2g_failure"},{"alarm_id":50000011,"event_start_ts":1518933506000,"event_end_ts":1518941321000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON187","MeContext":"LON187GSM2391"},"issue_type":"2g_failure"},{"alarm_id":50000012,"event_start_ts":1538952922000,"event_end_ts":1538956219000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON106","MeContext":"LON106LTE4901"},"issue_type":"hw_issue"},{"alarm_id":50000013,"event_start_ts":1535631870000,"event_end_ts":1535634717000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON181","MeContext":"LON181UTM3309"},"issue_type":"hw_issue"},{"alarm_id":50000014,"event_start_ts":1538235040000,"event_end_ts":1538241276000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON75","MeContext":"LON75UTM3265"},"issue_type":"up_link_failed"},{"alarm_id":50000015,"event_start_ts":1536314983000,"event_end_ts":1536323561000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON106","MeContext":"LON106GSM2550"},"issue_type":"3g_failure"},{"alarm_id":50000016,"event_start_ts":1543753807000,"event_end_ts":1543762963000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON71","MeContext":"LON71LTE4248"},"issue_type":""},{"alarm_id":50000017,"event_start_ts":1529425635000,"event_end_ts":1529428786000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON10","MeContext":"LON10UTM3556"},"issue_type":"up_link_failed"},{"alarm_id":50000018,"event_start_ts":1540550202000,"event_end_ts":1540556629000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON126","MeContext":"LON126UTM3553"},"issue_type":"battery_broken"},{"alarm_id":50000019,"event_start_ts":1532124021000,"event_end_ts":1532129030000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON114","MeContext":"LON114UTM3701"},"issue_type":"hw_issue"},{"alarm_id":50000020,"event_start_ts":1541918825000,"event_end_ts":1541927093000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON111","MeContext":"LON111UTM3087"},"issue_type":"2g_failure"},{"alarm_id":50000021,"event_start_ts":1531784282000,"event_end_ts":1531793043000,"alarm_src":{"Network":"UK_TEL_LON","SubNetwork":"LON19 ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# spark=SparkSession.builder.master("local[1]").appName("SQL").getOrCreate()
url="alarms.json"
df=spark.read.json(url)

# %%
df.show(truncate=False)
# Out:
# +--------+-----------------------------------+-------------+--------------+----------------+
# |alarm_id|alarm_src                          |event_end_ts |event_start_ts|issue_type      |
# +--------+-----------------------------------+-------------+--------------+----------------+
# |50000001|{LON75UTM3265, UK_TEL_LON, LON75}  |1525685613000|1525683343000 |                |
# |50000002|{LON47UTM3159, UK_TEL_LON, LON47}  |1533618469000|1533610843000 |                |
# |50000003|{LON75GSM2884, UK_TEL_LON, LON75}  |1541645693000|1541637429000 |3g_failure      |
# |50000004|{LON187GSM2391, UK_TEL_LON, LON187}|1525604682000|1525599471000 |power_failure   |
# |50000005|{LON111LTE4170, UK_TEL_LON, LON111}|1541342376000|1541335278000 |power_failure   |
# |50000006|{LON75GSM2884, UK_TEL_LON, LON75}  |1533844097000|1533841992000 |                |
# |50000007|{LON33GSM2601, UK_TEL_LON, LON33}  |1530752968000|1530743892000 |speed_issues    |
# |50000008|{LON187LTE4202, UK_TEL_LON, LON187}|1532234526000|1532227123000 |power_failure   |
# |50000009|{LON10UTM3870, UK_TEL_LON, LON10}  |1516540419000|1516535411000 |high_temperature|
# |50000010|{LON37GSM2364, UK_TEL_LON, LON37}  |1540334084000|1540331010000 |2g_failure      |
# |50000011|{LON187GSM2391, UK_TEL_LON, LON187}|1518941321000|1518933506000 |2g_failure      |
# |50000012|{LON106LTE4901, UK_TEL_LON, LON106}|1538956219000|1538952922000 |hw_issue        |
# |50000013|{LON181UTM3309, UK_TEL_LON, LON181}|1535634717000|1535631870000 |hw_issue        |
# |50000014|{LON75UTM3265, UK_TEL_LON, LON75}  |1538241276000|1538235040000 |up_link_failed  |
# |50000015|{LON106GSM2550, UK_TEL_LON, LON106}|1536323561000|1536314983000 |3g_failure      |
# |50000016|{LON71LTE4248, UK_TEL_LON, LON71}  |1543762963000|1543753807000 |                |
# |50000017|{LON10UTM3556, UK_TEL_LON, LON10}  |1529428786000|1529425635000 |up_link_failed  |
# |50000018|{LON126UTM3553, UK_TEL_LON, LON126}|1540556629000|1540550202000 |battery_broken  |
# |50000019|{LON114UTM3701, UK_TEL_LON, LON114}|1532129030000|1532124021000 |hw_issue        |
# |50000020|{LON111UTM3087, UK_TEL_LON, LON111}|1541927093000|1541918825000 |2g_failure      |
# +--------+-----------------------------------+-------------+--------------+----------------+
# only showing top 20 rows

# %%
df.createOrReplaceTempView("tmp_df_data")

# %%
spark.sql("select issue_type,COUNT(*) from tmp_df_data  group by issue_type order by COUNT(*) desc  ").show(100)
#issue with null alue
# Out:
# +-------------------+--------+
# |         issue_type|count(1)|
# +-------------------+--------+
# |                   |    5013|
# |           hw_issue|    3262|
# |    alignment_issue|    3261|
# |         2g_failure|    3258|
# |      power_failure|    3253|
# |     battery_broken|    3236|
# |   high_temperature|    3232|
# |    machine_failure|    3229|
# |       cell_failure|    3202|
# |       speed_issues|    3200|
# |network_unreachable|    3196|
# |         3g_failure|    3193|
# |         4g_failure|    3192|
# |     up_link_failed|    3189|
# |   down_link_failed|    3084|
# +-------------------+--------+

# %% [markdown]
# ### Question 3
#
# A simple initial definition of performance, is agreed to be the number of tickets a team resolves.
#
# To better understand the variances produce a table showing:
#
# - team
# - tickets_priority_1_count
# - tickets_priority_2_count
# - tickets_priority_3_count

# %%
# !rm -rf tickets.dat
# !wget https://raw.githubusercontent.com/vishnoiprem/honest-colab/main/tickets.dat
# !ls -lrt
# Out:
# --2022-10-08 02:35:07--  https://raw.githubusercontent.com/vishnoiprem/honest-colab/main/tickets.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2163571 (2.1M) [text/plain]
# Saving to: ‘tickets.dat’
#
# tickets.dat         100%[===================>]   2.06M  --.-KB/s    in 0.01s
#
# 2022-10-08 02:35:07 (211 MB/s) - ‘tickets.dat’ saved [2163571/2163571]
#
# total 15908
# drwxr-xr-x 1 root root    4096 Oct  5 13:35 sample_data
# -rw-r--r-- 1 root root 9785106 Oct  8 02:24 alarms.json
# -rw-r--r-- 1 root root 2163571 Oct  8 02:34 tickets.dat.1
# -rw-r--r-- 1 root root 2163571 Oct  8 02:34 tickets.dat.2
# -rw-r--r-- 1 root root 2163571 Oct  8 02:35 tickets.dat

# %%
# !ls -lrt
# !head tickets.dat
# Out:
# total 15908
# drwxr-xr-x 1 root root    4096 Oct  5 13:35 sample_data
# -rw-r--r-- 1 root root 9785106 Oct  8 02:24 alarms.json
# -rw-r--r-- 1 root root 2163571 Oct  8 02:34 tickets.dat.1
# -rw-r--r-- 1 root root 2163571 Oct  8 02:34 tickets.dat.2
# -rw-r--r-- 1 root root 2163571 Oct  8 02:35 tickets.dat
# ticket_id|alarm|started_ts|ended_ts|solved_by|src_system|site_visit|priority
# T_0000001|50025222|2018-09-14 03:29:10|14-09-2018 04.06.13|team78|OP2|1|3
# T_0000002|50021238|2018-10-29 03:39:49|29/10/2018 04:25:25|team30|OP1|0|2
# T_0000003|50034089|2018-03-31 07:25:48|31/03/2018 07:58:45|team68|OP1|0|3
# T_0000004|50021918|2018-08-08 19:57:56|08/08/2018 20:42:40|team56|OP1|0|2
# T_0000005|50046096|2018-10-10 17:47:00|10/10/2018 18:31:05|team34|OP1|0|3
# T_0000006|50023937|2018-11-18 06:20:17|18/11/2018 07:08:09|team48|OP1|0|3
# T_0000007|50014731|2018-03-05 01:01:29|05/03/2018 01:43:58|team30|OP1|0|3
# T_0000008|50005680|2018-04-22 19:40:41|22/04/2018 20:27:56|team34|OP1|1|3
# T_0000009|50019568|2018-03-09 10:33:47|09-03-2018 11.05.04|team34|OP2|0|1

# %%
# Your Answer

# spark.sql("select * from tmp_df_data   ").show(truncate=False)

dat_file='tickets.dat'
df1=spark.read.csv(dat_file,sep="|",inferSchema=True,header=True)

df1.columns
# Out:
# ['ticket_id',
#  'alarm',
#  'started_ts',
#  'ended_ts',
#  'solved_by',
#  'src_system',
#  'site_visit',
#  'priority']

# %%
df1.createOrReplaceTempView("tmp_df_data_tkt")
spark.sql("select priority,solved_by, COUNT(*) from tmp_df_data_tkt  group by  priority,solved_by  ").show(100)
# spark.sql("select case when priority= then ,solved_by, COUNT(*) from tmp_df_data_tkt  group by  priority,solved_by  ").show(100)
# Out:
# +--------+---------+--------+
# |priority|solved_by|count(1)|
# +--------+---------+--------+
# |       3|   team78|    1893|
# |       3|   team34|    1749|
# |       1|   team34|     405|
# |       1|   team56|     356|
# |       1|   team30|     354|
# |       1|   team48|     405|
# |       1|   team78|     400|
# |       2|   team33|    1152|
# |       2|   team90|    1111|
# |       2|   team56|    1139|
# |       1|   team68|     317|
# |       3|   team56|    1859|
# |       3|   team68|    1865|
# |       3|   team30|    1863|
# |       2|   team30|    1133|
# |       1|   team33|     364|
# |       2|   team68|    1172|
# |       3|   team48|    1898|
# |       1|   team28|     434|
# |       3|   team28|    1800|
# |       3|   team90|    1842|
# |       1|   team90|     360|
# |       2|   team34|    1064|
# |       2|   team78|    1114|
# |       2|   team28|    1071|
# |       2|   team48|    1093|
# |       3|   team33|    1787|
# +--------+---------+--------+

# %%
sql_query="""
select
solved_by as team,
COUNT(case when priority='1'  THEN  ticket_id  ELSE NULL END)  AS  tickets_priority_1_count,
COUNT(case when priority='2'  THEN ticket_id  ELSE NULL END)  AS  tickets_priority_2_count,
COUNT(case when priority='3'  THEN ticket_id  ELSE NULL END)  AS  tickets_priority_3_count

FROM 
tmp_df_data_tkt
group BY solved_by

"""


spark.sql(sql_query).show(100)
# Out:
# +------+------------------------+------------------------+------------------------+
# |  team|tickets_priority_1_count|tickets_priority_2_count|tickets_priority_3_count|
# +------+------------------------+------------------------+------------------------+
# |team68|                     317|                    1172|                    1865|
# |team56|                     356|                    1139|                    1859|
# |team48|                     405|                    1093|                    1898|
# |team30|                     354|                    1133|                    1863|
# |team78|                     400|                    1114|                    1893|
# |team28|                     434|                    1071|                    1800|
# |team90|                     360|                    1111|                    1842|
# |team33|                     364|                    1152|                    1787|
# |team34|                     405|                    1064|                    1749|
# +------+------------------------+------------------------+------------------------+

# %%
# Example output schema (using generated mock data)
import pandas as pd
import numpy as np
teams = ['team78', 'team30', 'team68', 'team56', 'team34', 'team48',
       'team28', 'team33', 'team90']
example_output_q3 = pd.DataFrame(
    {'team': np.random.choice(teams, 24),
     'tickets_priority_1_count': np.random.randint(0,100,24),
     'tickets_priority_2_count': np.random.randint(0,100,24),
     'tickets_priority_3_count': np.random.randint(0,100,24)}
)
example_output_q3.head()
# Out:
#      team  tickets_priority_1_count  tickets_priority_2_count  \
# 0  team28                        50                        22
# 1  team48                        16                        59
# 2  team78                        65                        21
# 3  team34                        26                        38
# 4  team30                        45                        61
#
#    tickets_priority_3_count
# 0                        25
# 1                        98
# 2                        14
# 3                        99
# 4                        29

# %% [markdown]
# ### Question 4
#
# As input to the early model effort create a dataframe with:
#
# - year
# - month
# - team
# - team size
# - tickets solved in the current month
# - tickets solved in the previous year

# %%
# !wget https://raw.githubusercontent.com/vishnoiprem/honest-colab/main/team.csv
# Out:
# --2022-10-08 02:47:23--  https://raw.githubusercontent.com/vishnoiprem/honest-colab/main/team.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 159 [text/plain]
# Saving to: ‘team.csv’
#
# team.csv            100%[===================>]     159  --.-KB/s    in 0s
#
# 2022-10-08 02:47:24 (11.5 MB/s) - ‘team.csv’ saved [159/159]

# %%
# !ls -lrt
# Out:
# total 15912
# drwxr-xr-x 1 root root    4096 Oct  5 13:35 sample_data
# -rw-r--r-- 1 root root 9785106 Oct  8 02:24 alarms.json
# -rw-r--r-- 1 root root 2163571 Oct  8 02:34 tickets.dat.1
# -rw-r--r-- 1 root root 2163571 Oct  8 02:34 tickets.dat.2
# -rw-r--r-- 1 root root 2163571 Oct  8 02:35 tickets.dat
# -rw-r--r-- 1 root root     159 Oct  8 02:47 team.csv

# %%
# Your Answer

team="team.csv"

team_csv=spark.read.csv(team,sep=",",inferSchema=True,header=True)

team_csv
# Out:
# DataFrame[team_id: string, team_size: int, avg_experience_years: int]

# %%
team_csv.createOrReplaceTempView("tmp_team_vw")

spark.sql("select * FROM tmp_team_vw order by team_size desc ").show()
# Out:
# +-------+---------+--------------------+
# |team_id|team_size|avg_experience_years|
# +-------+---------+--------------------+
# |team028|        6|                   6|
# |team030|        6|                   6|
# |team033|        6|                   7|
# |team048|        6|                   6|
# |team056|        5|                   8|
# |team078|        5|                   8|
# |team090|        5|                   6|
# |team068|        5|                   5|
# |team040|        4|                   5|
# |team034|        3|                   6|
# +-------+---------+--------------------+

# %%
spark.sql("select * FROM tmp_df_data_tkt").show()
# Out:
# +---------+--------+-------------------+-------------------+---------+----------+----------+--------+
# |ticket_id|   alarm|         started_ts|           ended_ts|solved_by|src_system|site_visit|priority|
# +---------+--------+-------------------+-------------------+---------+----------+----------+--------+
# |T_0000001|50025222|2018-09-14 03:29:10|14-09-2018 04.06.13|   team78|       OP2|         1|       3|
# |T_0000002|50021238|2018-10-29 03:39:49|29/10/2018 04:25:25|   team30|       OP1|         0|       2|
# |T_0000003|50034089|2018-03-31 07:25:48|31/03/2018 07:58:45|   team68|       OP1|         0|       3|
# |T_0000004|50021918|2018-08-08 19:57:56|08/08/2018 20:42:40|   team56|       OP1|         0|       2|
# |T_0000005|50046096|2018-10-10 17:47:00|10/10/2018 18:31:05|   team34|       OP1|         0|       3|
# |T_0000006|50023937|2018-11-18 06:20:17|18/11/2018 07:08:09|   team48|       OP1|         0|       3|
# |T_0000007|50014731|2018-03-05 01:01:29|05/03/2018 01:43:58|   team30|       OP1|         0|       3|
# |T_0000008|50005680|2018-04-22 19:40:41|22/04/2018 20:27:56|   team34|       OP1|         1|       3|
# |T_0000009|50019568|2018-03-09 10:33:47|09-03-2018 11.05.04|   team34|       OP2|         0|       1|
# |T_0000010|50021490|2018-02-18 03:17:54|18/02/2018 04:10:12|   team68|       OP1|         1|       3|
# |T_0000011|50031715|2018-01-17 10:10:12|17-01-2018 10.59.56|   team28|       OP2|         0|       3|
# |T_0000012|50020307|2018-11-13 04:30:58|13/11/2018 05:20:12|   team28|       OP1|         0|       3|
# |T_0000013|50025022|2018-09-22 18:53:09|22-09-2018 19.25.44|   team56|       OP2|         0|       2|
# |T_0000014|50009585|2018-02-04 22:31:39|04/02/2018 23:06:18|   team30|       OP1|         1|       3|
# |T_0000015|50047314|2018-06-05 00:44:29|05-06-2018 01.20.33|   team28|       OP2|         1|       3|
# |T_0000016|50016133|2018-03-03 23:37:08|04-03-2018 00.16.33|   team56|       OP2|         0|       1|
# |T_0000017|50029254|2018-11-19 13:14:11|19/11/2018 14:13:59|   team33|       OP1|         0|       2|
# |T_0000018|50011198|2018-05-13 15:31:09|13/05/2018 16:16:03|   team90|       OP1|         0|       2|
# |T_0000019|50010378|2018-01-04 06:22:13|               null|   team28|       OP2|         0|       3|
# |T_0000020|50037567|2018-12-13 05:30:25|               null|   team56|       OP1|         1|       3|
# +---------+--------+-------------------+-------------------+---------+----------+----------+--------+
# only showing top 20 rows

# %%
sql_df="""
select 
tkt.ticket_id,
tkt.alarm,
tkt.started_ts,
tkt.ended_ts,
tkt.solved_by,
tkt.src_system,
tkt.site_visit,
tkt.priority,
t.team_size
FROM tmp_df_data_tkt as tkt
LEFT JOIN (SELECT team_size , replace (team_id,'team0','team') as team_id FROM tmp_team_vw) as t ON (t.team_id=tkt.solved_by)
"""
spark.sql(sql_df).show(10)
# Out:
# +---------+--------+-------------------+-------------------+---------+----------+----------+--------+---------+
# |ticket_id|   alarm|         started_ts|           ended_ts|solved_by|src_system|site_visit|priority|team_size|
# +---------+--------+-------------------+-------------------+---------+----------+----------+--------+---------+
# |T_0000001|50025222|2018-09-14 03:29:10|14-09-2018 04.06.13|   team78|       OP2|         1|       3|        5|
# |T_0000002|50021238|2018-10-29 03:39:49|29/10/2018 04:25:25|   team30|       OP1|         0|       2|        6|
# |T_0000003|50034089|2018-03-31 07:25:48|31/03/2018 07:58:45|   team68|       OP1|         0|       3|        5|
# |T_0000004|50021918|2018-08-08 19:57:56|08/08/2018 20:42:40|   team56|       OP1|         0|       2|        5|
# |T_0000005|50046096|2018-10-10 17:47:00|10/10/2018 18:31:05|   team34|       OP1|         0|       3|        3|
# |T_0000006|50023937|2018-11-18 06:20:17|18/11/2018 07:08:09|   team48|       OP1|         0|       3|        6|
# |T_0000007|50014731|2018-03-05 01:01:29|05/03/2018 01:43:58|   team30|       OP1|         0|       3|        6|
# |T_0000008|50005680|2018-04-22 19:40:41|22/04/2018 20:27:56|   team34|       OP1|         1|       3|        3|
# |T_0000009|50019568|2018-03-09 10:33:47|09-03-2018 11.05.04|   team34|       OP2|         0|       1|        3|
# |T_0000010|50021490|2018-02-18 03:17:54|18/02/2018 04:10:12|   team68|       OP1|         1|       3|        5|
# +---------+--------+-------------------+-------------------+---------+----------+----------+--------+---------+
# only showing top 10 rows

# %%
from pyspark.sql.functions import *
from  pyspark.sql.functions import lag

# %%
sql_df="""


select 
tkt.solved_by
,t.team_size
,year(  started_ts) as year
,month(  started_ts) as month
,COUNT(*) as tickets_solved
FROM tmp_df_data_tkt as tkt
LEFT JOIN (SELECT team_size , replace (team_id,'team0','team') as team_id FROM tmp_team_vw) as t ON (t.team_id=tkt.solved_by)
where t.team_size=6
group by 
year(  started_ts)  ,
month(  started_ts) ,
tkt.solved_by,
t.team_size
order by solved_by,month
"""
spark.sql(sql_df).show(10)
# Out:
# +---------+---------+----+-----+--------------+
# |solved_by|team_size|year|month|tickets_solved|
# +---------+---------+----+-----+--------------+
# |   team28|        6|2018|    1|           279|
# |   team28|        6|2019|    1|             1|
# |   team28|        6|2018|    2|           229|
# |   team28|        6|2018|    3|           291|
# |   team28|        6|2018|    4|           300|
# |   team28|        6|2018|    5|           266|
# |   team28|        6|2018|    6|           311|
# |   team28|        6|2018|    7|           291|
# |   team28|        6|2018|    8|           268|
# |   team28|        6|2018|    9|           263|
# +---------+---------+----+-----+--------------+
# only showing top 10 rows

# %%
sql_df="""

select 
year,
month,
solved_by as team,
team_size,
tickets_solved as tickets_solved_in_the_current_month,
lag(tickets_solved) over (partition by solved_by,year order by month  ) tickets_solved_in_the_previous_year
FROM
(select 
tkt.solved_by
,t.team_size
,year(  started_ts) as year
,month(  started_ts) as month
,COUNT(*) as tickets_solved
FROM tmp_df_data_tkt as tkt
LEFT JOIN (SELECT team_size , replace (team_id,'team0','team') as team_id FROM tmp_team_vw) as t ON (t.team_id=tkt.solved_by)
group by 
year(  started_ts)  ,
month(  started_ts) ,
tkt.solved_by,
t.team_size
)a
"""
spark.sql(sql_df).show(10)
# Out:
# +----+-----+------+---------+-----------------------------------+-----------------------------------+
# |year|month|  team|team_size|tickets_solved_in_the_current_month|tickets_solved_in_the_previous_year|
# +----+-----+------+---------+-----------------------------------+-----------------------------------+
# |2018|    1|team28|        6|                                279|                               null|
# |2018|    2|team28|        6|                                229|                                279|
# |2018|    3|team28|        6|                                291|                                229|
# |2018|    4|team28|        6|                                300|                                291|
# |2018|    5|team28|        6|                                266|                                300|
# |2018|    6|team28|        6|                                311|                                266|
# |2018|    7|team28|        6|                                291|                                311|
# |2018|    8|team28|        6|                                268|                                291|
# |2018|    9|team28|        6|                                263|                                268|
# |2018|   10|team28|        6|                                277|                                263|
# +----+-----+------+---------+-----------------------------------+-----------------------------------+
# only showing top 10 rows

# %%
# Example output schema (using generated mock data)
import pandas as pd
import numpy as np
teams = ['team78', 'team30', 'team68', 'team56', 'team34', 'team48',
       'team28', 'team33', 'team90']
example_output_q4 = pd.DataFrame(
    {'year': [2018]*12 + [2019]*12,
     'month': list(range(1,13))*2,
     'team': np.random.choice(teams, 24),
     'team_size': np.random.randint(1,6,24),
     'tickets_solved_in_the_current_month': np.random.randint(0,100,24),
     'tickets_solved_in_the_previous_year': np.random.randint(0,100,24)}
)
example_output_q4.head()
# Out:
#    year  month    team  team_size  tickets_solved_in_the_current_month  \
# 0  2018      1  team78          4                                   96
# 1  2018      2  team48          3                                   73
# 2  2018      3  team90          5                                   42
# 3  2018      4  team48          2                                   33
# 4  2018      5  team48          2                                   65
#
#    tickets_solved_in_the_previous_year
# 0                                   52
# 1                                   69
# 2                                   34
# 3                                   90
# 4                                   77

# %% [markdown]
# ### Question 5
#
# A hypothesis is that the teams working on newer towers will take longer to resolve issues.
#
# A colleague began work on the below, but has left it unfinished...
#
# Create a function that accepts alarms records (or subparts) and returns the alarm network type.
#
# This is a chance to demonstrate your software engineering skills. Make sure this function is robust & ready for PR; consider testing & documentation.

# %%
# Your Answer
def myFunc(json_string):
    # todo fix me
    
    try:
        if 'GSM' in json_string['alarm_src']['MeContext']:
            return "2G"
        elif 'UTM' in json_string['alarm_src']['MeContext']:
            return "3G"
        elif  'LTE' in json_string['alarm_src']['MeContext'] :
            return "4G"

        else:
            return None

    except:
        return "invalid Json"

# %% [raw]
# spark.sql("select * from tmp_df_data   ").show(truncate=False)

# %%
import json
  
f = open('alarms.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)
  
# Iterating through the json
# list
count=10
for i in data:
    print(i)
    count+=1
    json_string=i
    print(myFunc(json_string))
    break

  
# Closing file
f.close()
# Out:
# {'alarm_id': 50000001, 'event_start_ts': 1525683343000, 'event_end_ts': 1525685613000, 'alarm_src': {'Network': 'UK_TEL_LON', 'SubNetwork': 'LON75', 'MeContext': 'LON75UTM3265'}, 'issue_type': ''}
# 3G

# %%
json_string
# Out:
# {'alarm_id': 50000001,
#  'event_start_ts': 1525683343000,
#  'event_end_ts': 1525685613000,
#  'alarm_src': {'Network': 'UK_TEL_LON',
#   'SubNetwork': 'LON75',
#   'MeContext': 'LON75UTM3265'},
#  'issue_type': ''}

# %%
print(myFunc(json_string))
# Out:
# 3G
